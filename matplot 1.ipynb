# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[23,24,32,29,35]
z=[24,45,35,42,45]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='green',linewidth=5)

# %%
plt.xlabel('day')
plt.ylabel('min_temprature')
plt.zlabel('max_temprature')
plt.title('whether')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 plt.xlabel('day')
#       2 plt.ylabel('min_temprature')
# ----> 3 plt.zlabel('max_temprature')
#       4 plt.title('whether')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'

# %%
plt.plot(x,y)
plt.plot(x,z)

# %%
plt.xlabel('day')
plt.ylabel('min_temprature')
plt.zlabel('max_temprature')
plt.title('whether')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 plt.xlabel('day')
#       2 plt.ylabel('min_temprature')
# ----> 3 plt.zlabel('max_temprature')
#       4 plt.title('whether')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'
