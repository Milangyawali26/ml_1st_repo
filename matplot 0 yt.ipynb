# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
company=['google','amzn','msct','fb']
revenue=[90,136,54,64]
profit=[40,13,25,25]

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(ypos,company)
plt.ylabel("revenue(bln)")
plt.title("us tech stocks")
plt.bar(xpos-0.2,revenue,width=0.4,label='revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='profit')
plt.legend()

# %%
blood_sugar_man=[113,85,90,96,115,148,75,117,89]
blood_sugar_woman=[67,87,97,69,86,117,96,83,83,134]
 
plt.hist([blood_sugar_man,blood_sugar_woman],bins=[80,100,125,150],rwidth=0.95,color=['g','r'],label=['man','woman'])
plt.legend()

# %%
exp_values=[1400,600,300,410,250]
exp_labels=['home rent','food','phone/internet','car','other']

# %%
plt.axis('equal')
plt.pie(exp_values, labels=exp_labels, radius=1,autopct='%0.2f%%',shadow='true',
        explode=[0,0.2,0,0,0],startangle=120)
plt.show()
plt.sav
